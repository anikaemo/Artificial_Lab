# %% [markdown]
# <a href="https://colab.research.google.com/github/anikaemo/Artificial_Lab/blob/main/diabetes_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT LIBRARY
import pandas as pd

# %%
#Empty df
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: []
# Index: []>

# %%
#import excel file
df = pd.read_csv('/content/diabetes (1).csv')
df
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail()
# Out:
#      Number of times pregnant  \
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 763                                                101
# 764                                                122
# 765                                                121
# 766                                                126
# 767                                                 93
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 763                                76                                48
# 764                                70                                27
# 765                                72                                23
# 766                                60                                 0
# ...

# %%
df.head()
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# the shape of df

# %%
df.shape
# Out:
# (768, 9)

# %%
rows, cols = df.shape

# %%
rows
# Out:
# 768

# %%
cols
# Out:
# 9

# %% [markdown]
# print the values of df

# %%
print(df.values)
# Out:
# [[  6.    148.     72.    ...   0.627  50.      1.   ]
#  [  1.     85.     66.    ...   0.351  31.      0.   ]
#  [  8.    183.     64.    ...   0.672  32.      1.   ]
#  ...
#  [  5.    121.     72.    ...   0.245  30.      0.   ]
#  [  1.    126.     60.    ...   0.349  47.      1.   ]
#  [  1.     93.     70.    ...   0.315  23.      0.   ]]

# %%
#print the column index of df
print(df.columns)
# Out:
# Index(['Number of times pregnant',
#        'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skin fold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age (years)', 'Class variable'],
#       dtype='object')

# %%
#print the row index of df
print(df.index)
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
df.head(5)
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
#Specific column
df [['Triceps skin fold thickness (mm)']]
# Out:
#      Triceps skin fold thickness (mm)
# 0                                  35
# 1                                  29
# 2                                   0
# 3                                  23
# 4                                  35
# ..                                ...
# 763                                48
# 764                                27
# 765                                23
# 766                                 0
# 767                                31
#
# [768 rows x 1 columns]

# %%
df[['Number of times pregnant', 'Diastolic blood pressure (mm Hg)']] .head(10)
# Out:
#    Number of times pregnant  Diastolic blood pressure (mm Hg)
# 0                         6                                72
# 1                         1                                66
# 2                         8                                64
# 3                         1                                66
# 4                         0                                40
# 5                         5                                74
# 6                         3                                50
# 7                        10                                 0
# 8                         2                                70
# 9                         8                                96

# %%
df ['Diabetes pedigree function'].sort_values()
# Out:
# 268    0.078
# 180    0.084
# 567    0.085
# 149    0.085
# 135    0.088
#        ...
# 45     1.893
# 370    2.137
# 4      2.288
# 228    2.329
# 445    2.420
# Name: Diabetes pedigree function, Length: 768, dtype: float64

# %%
df.sort_values('Diabetes pedigree function', ascending=False)
# Out:
#      Number of times pregnant  \
# 445                         0
# 228                         4
# 4                           0
# 370                         3
# 45                          0
# ..                        ...
# 598                         1
# 567                         6
# 149                         2
# 180                         6
# 268                         0
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 445                                                180
# 228                                                197
# 4                                                  137
# 370                                                173
# 45                                                 180
# ..                                                 ...
# 598                                                173
# 567                                                 92
# 149                                                 90
# ...

# %%
df.sort_values('Diabetes pedigree function', ascending=True)
# Out:
#      Number of times pregnant  \
# 268                         0
# 180                         6
# 567                         6
# 149                         2
# 135                         2
# ..                        ...
# 45                          0
# 370                         3
# 4                           0
# 228                         4
# 445                         0
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 268                                                102
# 180                                                 87
# 567                                                 92
# 149                                                 90
# 135                                                125
# ..                                                 ...
# 45                                                 180
# 370                                                173
# 4                                                  137
# ...

# %%
df.sort_values('Diabetes pedigree function', ascending=False)
# Out:
#      Number of times pregnant  \
# 445                         0
# 228                         4
# 4                           0
# 370                         3
# 45                          0
# ..                        ...
# 598                         1
# 567                         6
# 149                         2
# 180                         6
# 268                         0
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 445                                                180
# 228                                                197
# 4                                                  137
# 370                                                173
# 45                                                 180
# ..                                                 ...
# 598                                                173
# 567                                                 92
# 149                                                 90
# ...

# %%
#Statistical Analysis
df.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
#Correlation
df.corr()
# Out:
#                                                     Number of times pregnant  \
# Number of times pregnant                                            1.000000
# Plasma glucose concentration a 2 hours in an or...                  0.129459
# Diastolic blood pressure (mm Hg)                                    0.141282
# Triceps skin fold thickness (mm)                                   -0.081672
# 2-Hour serum insulin (mu U/ml)                                     -0.073535
# Body mass index (weight in kg/(height in m)^2)                      0.017683
# Diabetes pedigree function                                         -0.033523
# Age (years)                                                         0.544341
# Class variable                                                      0.221898
#
#                                                     Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
#Subseting rows
df[df['Body mass index (weight in kg/(height in m)^2)'] > 40 ]
# Out:
#      Number of times pregnant  \
# 4                           0
# 16                          0
# 18                          1
# 41                          7
# 43                          9
# ..                        ...
# 744                        13
# 746                         1
# 747                         1
# 753                         0
# 761                         9
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 4                                                  137
# 16                                                 118
# 18                                                 103
# 41                                                 133
# 43                                                 171
# ..                                                 ...
# 744                                                153
# 746                                                147
# 747                                                 81
# ...

# %%
#Subseting rows
df[(df['Body mass index (weight in kg/(height in m)^2)'] < 40) |
   (df['Body mass index (weight in kg/(height in m)^2)'] > 30)]
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
#Subseting using isin()
df[df['Body mass index (weight in kg/(height in m)^2)'].isin([30,40])]
# Out:
#      Number of times pregnant  \
# 15                          7
# 217                         6
# 245                         9
# 261                         3
# 267                         2
# 432                         1
# 468                         8
# 606                         1
# 745                        12
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 15                                                 100
# 217                                                125
# 245                                                184
# 261                                                141
# 267                                                128
# 432                                                 80
# 468                                                120
# 606                                                181
# 745                                                100
#
#      Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
#Missing Value Check
df.isnull()
# Out:
#      Number of times pregnant  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 763                     False
# 764                     False
# 765                     False
# 766                     False
# 767                     False
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 763                                              False
# 764                                              False
# 765                                              False
# ...

# %%
#Duplicate Value Check
print("Duplicate rows:", df.duplicated())
# Out:
# Duplicate rows: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool
